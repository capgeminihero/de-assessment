# %% [markdown]
# # DE Assessment — Data Exploration
# Use this notebook for ingestion, transformation, and exploration tasks.

# %%
import pandas as pd
# import pyspark if using Databricks / Spark environment

# %% [markdown]
# ## 1. Ingestion

# %%
# df = pd.read_csv('path/to/data.csv')
# df.head()

# %% [markdown]
# ## 2. Transformation

# %%
# Clean, filter, join etc.
# df_clean = df.dropna()

# %% [markdown]
# ## 3. Exploration & Analysis

# %%
# df_clean.describe()
# df_clean.plot()
